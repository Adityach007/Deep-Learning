# %% [markdown]
# In this project, we will create a Convolutional Neural Network which will able ot predict whethe a plant is suffering from a disease. We will use different layers and other hyperparameters for building, training and testing this classification model. We will be using tensorflow and keras for this project.

# %%
# Load the drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# First we will mount our drive on colab so that we can use the dataset directly from our drive. For this you first need to upload the data on your drive and then mount the drive on colab.

# %%
# !ls "/content/drive/My Drive"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.image import imread
import cv2
import random
import os
from os import listdir
from PIL import Image
from sklearn.preprocessing import label_binarize,  LabelBinarizer
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array, array_to_img
from keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dropout, Dense
from sklearn.model_selection import train_test_split
from keras.models import model_from_json
from keras.utils import to_categorical

# %% [markdown]
# Next we will import all the required libraries. As we are making a CNN model we will import all the required layers, activations, optimizers, etc.

# %%
# Plotting 12 images to check dataset
plt.figure(figsize=(12,12))
path = "/content/drive/My Drive/Plant_images/Potato___Early_blight"
for i in range(1,17):
    plt.subplot(4,4,i)
    plt.tight_layout()
    rand_img = imread(path +'/'+ random.choice(sorted(os.listdir(path))))
    plt.imshow(rand_img)
    plt.xlabel(rand_img.shape[1], fontsize = 10)#width of image
    plt.ylabel(rand_img.shape[0], fontsize = 10)#height of image

# %% [markdown]
# Now we will observe some of the images that are their in our dataset. We will plot 12 images here using the matplotlib library.

# %%
#Converting Images to array
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, (256,256))
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %% [markdown]
# After visualizing the images let us move forward and create a function which will convert the images into a numpy array. It is required because we will normalize our dataset after this.

# %%
dir = "/content/drive/My Drive/Plant_images"
root_dir = listdir(dir)
image_list, label_list = [], []
all_labels = ['Corn-Common_rust', 'Potato-Early_blight', 'Tomato-Bacterial_spot']
binary_labels = [0,1,2]
temp = -1

# Reading and converting image to numpy array
for directory in root_dir:
  plant_image_list = listdir(f"{dir}/{directory}")
  temp += 1
  for files in plant_image_list:
    image_path = f"{dir}/{directory}/{files}"
    image_list.append(convert_image_to_array(image_path))
    label_list.append(binary_labels[temp])

# %% [markdown]
# Now we will convert all the images into numpy array

# %%
# Visualize the number of classes count
label_counts = pd.DataFrame(label_list).value_counts()
label_counts.head()
# Out:
# 2    306
# 0    300
# 1    300
# dtype: int64

# %% [markdown]
# We will also observe the number of images under different classes to see if the dataset is balanced or not.

# %%
image_list[0].shape
# Out:
# (256, 256, 3)

# %% [markdown]
# Next we will observe the shape of the image.

# %%
label_list = np.array(label_list)
label_list.shape
# Out:
# (906,)

# %% [markdown]
# Checking the total number of the images which is the length of the labels list.

# %%
x_train, x_test, y_train, y_test = train_test_split(image_list, label_list, test_size=0.2, random_state = 10)

# %% [markdown]
# Next we will use sklearn train_test_split to split the dataset into testing and training data. Here I have taken test size as 0.2 so my data will be divided into 80% training and 20% testing data.

# %%
x_train = np.array(x_train, dtype=np.float16) / 225.0
x_test = np.array(x_test, dtype=np.float16) / 225.0
x_train = x_train.reshape( -1, 256,256,3)
x_test = x_test.reshape( -1, 256,256,3)

# %% [markdown]
# Now we will normalize the dataset of our images. As pixel values ranges from 0 to 255 so we will divide each image pixel with 255 to normalize the dataset.

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), padding="same",input_shape=(256,256,3), activation="relu"))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Conv2D(16, (3, 3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(8, activation="relu"))
model.add(Dense(3, activation="softmax"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 256, 256, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 85, 85, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 85, 85, 16)        4624
#
#  max_pooling2d_1 (MaxPoolin  (None, 42, 42, 16)        0
#  g2D)
#
#  flatten (Flatten)           (None, 28224)             0
#
#  dense (Dense)               (None, 8)                 225800
#
#  dense_1 (Dense)             (None, 3)                 27
#
# =================================================================
# Total params: 231347 (903.70 KB)
# Trainable params: 231347 (903.70 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Next we will create a network architecture for the model. We have used different types of layers according to their features namely Conv_2d (It is used to create a convolutional kernel that is convolved with the input layer to produce the output tensor), max_pooling2d (It is a downsampling technique which takes out the maximum value over the window defined by poolsize), flatten (It flattens the input and creates a 1D output), Dense (Dense layer produce the output as the dot product of input and kernel).

# %%
model.compile(loss = 'categorical_crossentropy', optimizer = Adam(0.0001),metrics=['accuracy'])

# %% [markdown]
# While compiling the model we need to set the type of loss which will be Binary Crossentropy for our model alongwith this we also need to set the optimizer and the metrics respectively.

# %%
# Splitting the training data set into training and validation data sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2)

# %% [markdown]
# Next we will split the dataset into validation and training data.

# %%
# Training the model
epochs = 50
batch_size = 128
history = model.fit(x_train, y_train, batch_size = batch_size, epochs = epochs,
                    validation_data = (x_val, y_val))
# Out:
# Epoch 1/50
# 5/5 [==============================] - 50s 10s/step - loss: 1.0029 - accuracy: 0.4370 - val_loss: 0.8828 - val_accuracy: 0.6345
# Epoch 2/50
# 5/5 [==============================] - 37s 7s/step - loss: 0.8360 - accuracy: 0.7047 - val_loss: 0.7221 - val_accuracy: 0.8483
# Epoch 3/50
# 5/5 [==============================] - 45s 10s/step - loss: 0.6791 - accuracy: 0.8687 - val_loss: 0.5765 - val_accuracy: 0.9172
# Epoch 4/50
# 5/5 [==============================] - 42s 8s/step - loss: 0.5491 - accuracy: 0.8739 - val_loss: 0.4494 - val_accuracy: 0.9517
# Epoch 5/50
# 5/5 [==============================] - 34s 7s/step - loss: 0.4454 - accuracy: 0.9292 - val_loss: 0.3910 - val_accuracy: 0.8897
# Epoch 6/50
# 5/5 [==============================] - 33s 6s/step - loss: 0.3608 - accuracy: 0.9292 - val_loss: 0.2849 - val_accuracy: 0.9517
# Epoch 7/50
# 5/5 [==============================] - 35s 7s/step - loss: 0.2968 - accuracy: 0.9344 - val_loss: 0.2594 - val_accuracy: 0.9379
# Epoch 8/50
# 5/5 [==============================] - 33s 7s/step - loss: 0.2476 - accuracy: 0.9413 - val_loss: 0.1824 - val_accuracy: 0.9724
# Epoch 9/50
# 5/5 [==============================] - 35s 7s/step - loss: 0.2069 - accuracy: 0.9482 - val_loss: 0.1583 - val_accuracy: 0.9724
# Epoch 10/50
# 5/5 [==============================] - 36s 7s/step - loss: 0.1696 - accuracy: 0.9603 - val_loss: 0.1371 - val_accuracy: 0.9793
# Epoch 11/50
# 5/5 [==============================] - 33s 7s/step - loss: 0.1450 - accuracy: 0.9585 - val_loss: 0.1309 - val_accuracy: 0.9586
# Epoch 12/50
# 5/5 [==============================] - 33s 7s/step - loss: 0.1192 - accuracy: 0.9672 - val_loss: 0.1118 - val_accuracy: 0.9724
# Epoch 13/50
# 5/5 [==============================] - 36s 7s/step - loss: 0.1041 - accuracy: 0.9827 - val_loss: 0.0755 - val_accuracy: 0.9862
# Epoch 14/50
# 5/5 [==============================] - 33s 7s/step - loss: 0.0981 - accuracy: 0.9741 - val_loss: 0.0704 - val_accuracy: 0.9862
# Epoch 15/50
# 5/5 [==============================] - 33s 7s/step - loss: 0.0794 - accuracy: 0.9810 - val_loss: 0.0902 - val_accuracy: 0.9724
# Epoch 16/50
# 5/5 [==============================] - 35s 7s/step - loss: 0.0682 - accuracy: 0.9862 - val_loss: 0.0642 - val_accuracy: 0.9931
# Epoch 17/50
# 5/5 [==============================] - 33s 7s/step - loss: 0.0605 - accuracy: 0.9896 - val_loss: 0.0548 - val_accuracy: 0.9862
# Epoch 18/50
# 5/5 [==============================] - 44s 9s/step - loss: 0.0613 - accuracy: 0.9862 - val_loss: 0.0798 - val_accuracy: 0.9724
# Epoch 19/50
# 5/5 [==============================] - 33s 7s/step - loss: 0.0468 - accuracy: 0.9948 - val_loss: 0.0444 - val_accuracy: 0.9931
# Epoch 20/50
# 5/5 [==============================] - 35s 7s/step - loss: 0.0475 - accuracy: 0.9931 - val_loss: 0.0465 - val_accuracy: 0.9931
# Epoch 21/50
# 5/5 [==============================] - 33s 7s/step - loss: 0.0387 - accuracy: 0.9965 - val_loss: 0.0492 - val_accuracy: 0.9862
# Epoch 22/50
# 5/5 [==============================] - 33s 7s/step - loss: 0.0336 - accuracy: 0.9983 - val_loss: 0.0397 - val_accuracy: 0.9931
# Epoch 23/50
# 5/5 [==============================] - 35s 7s/step - loss: 0.0304 - accuracy: 0.9965 - val_loss: 0.0431 - val_accuracy: 0.9931
# Epoch 24/50
# 5/5 [==============================] - 34s 7s/step - loss: 0.0279 - accuracy: 0.9983 - val_loss: 0.0354 - val_accuracy: 0.9931
# Epoch 25/50
# 5/5 [==============================] - 40s 7s/step - loss: 0.0250 - accuracy: 1.0000 - val_loss: 0.0430 - val_accuracy: 0.9862
# Epoch 26/50
# 5/5 [==============================] - 32s 7s/step - loss: 0.0233 - accuracy: 0.9983 - val_loss: 0.0322 - val_accuracy: 0.9931
# Epoch 27/50
# 5/5 [==============================] - 35s 7s/step - loss: 0.0219 - accuracy: 1.0000 - val_loss: 0.0369 - val_accuracy: 0.9931
# Epoch 28/50
# 5/5 [==============================] - 32s 7s/step - loss: 0.0197 - accuracy: 1.0000 - val_loss: 0.0329 - val_accuracy: 0.9931
# Epoch 29/50
# 5/5 [==============================] - 33s 6s/step - loss: 0.0187 - accuracy: 1.0000 - val_loss: 0.0374 - val_accuracy: 0.9862
# Epoch 30/50
# 5/5 [==============================] - 36s 7s/step - loss: 0.0176 - accuracy: 1.0000 - val_loss: 0.0327 - val_accuracy: 0.9931
# Epoch 31/50
# 5/5 [==============================] - 33s 7s/step - loss: 0.0158 - accuracy: 1.0000 - val_loss: 0.0325 - val_accuracy: 0.9931
# Epoch 32/50
# 5/5 [==============================] - 33s 6s/step - loss: 0.0145 - accuracy: 1.0000 - val_loss: 0.0303 - val_accuracy: 0.9931
# Epoch 33/50
# 5/5 [==============================] - 36s 7s/step - loss: 0.0137 - accuracy: 1.0000 - val_loss: 0.0287 - val_accuracy: 0.9931
# Epoch 34/50
# 5/5 [==============================] - 32s 7s/step - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.0280 - val_accuracy: 0.9931
# Epoch 35/50
# 5/5 [==============================] - 35s 7s/step - loss: 0.0126 - accuracy: 1.0000 - val_loss: 0.0309 - val_accuracy: 0.9931
# Epoch 36/50
# 5/5 [==============================] - 42s 7s/step - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.0270 - val_accuracy: 0.9931
# Epoch 37/50
# 5/5 [==============================] - 33s 6s/step - loss: 0.0127 - accuracy: 1.0000 - val_loss: 0.0291 - val_accuracy: 0.9931
# Epoch 38/50
# 5/5 [==============================] - 33s 7s/step - loss: 0.0114 - accuracy: 1.0000 - val_loss: 0.0228 - val_accuracy: 0.9931
# Epoch 39/50
# 5/5 [==============================] - 33s 7s/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.0405 - val_accuracy: 0.9793
# Epoch 40/50
# 5/5 [==============================] - 32s 6s/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.0198 - val_accuracy: 1.0000
# Epoch 41/50
# 5/5 [==============================] - 34s 7s/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.0301 - val_accuracy: 0.9931
# Epoch 42/50
# 5/5 [==============================] - 33s 7s/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.0258 - val_accuracy: 0.9931
# Epoch 43/50
# 5/5 [==============================] - 33s 6s/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.0232 - val_accuracy: 0.9931
# Epoch 44/50
# 5/5 [==============================] - 36s 7s/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.0278 - val_accuracy: 0.9931
# Epoch 45/50
# 5/5 [==============================] - 32s 7s/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.0240 - val_accuracy: 0.9931
# Epoch 46/50
# 5/5 [==============================] - 33s 6s/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.0281 - val_accuracy: 0.9931
# Epoch 47/50
# 5/5 [==============================] - 36s 7s/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.0202 - val_accuracy: 0.9931
# Epoch 48/50
# 5/5 [==============================] - 33s 7s/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0289 - val_accuracy: 0.9931
# Epoch 49/50
# 5/5 [==============================] - 33s 6s/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.0222 - val_accuracy: 0.9931
# Epoch 50/50
# 5/5 [==============================] - 34s 7s/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.0231 - val_accuracy: 0.9931

# %% [markdown]
# Fitting the model with the data and finding out the accuracy at each epoch to see how our model is learning. Now we will train our model on 10 epochs and a batch size of 128. You can try using more number of epochs to increase accuracy but here we can see that the model has already raeched a very high accuracy so we don't need to run it for more. During each epochs we can see how the model is performing by viewing the training and validation accuracy.

# %%
model.save("/content/drive/My Drive/plant_disease.h5")
# serialize model to json
json_model = model.to_json()
#save the model architecture to JSON file
with open('/content/drive/My Drive/plant_model.json', 'w') as json_file:
    json_file.write(json_model)
#saving the weights of the model
model.save_weights('/content/drive/My Drive/plant_model_weights.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# Saving the model using different techniques.

# %%
#Plot the training history
plt.figure(figsize=(12, 5))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])

plt.show()

# %% [markdown]
# Next we will plot the accuracy of the model for the trainig history.

# %%
print("[INFO] Calculating model accuracy")
scores = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 6/6 [==============================] - 3s 466ms/step - loss: 0.0997 - accuracy: 0.9835
# Test Accuracy: 98.35164546966553

# %% [markdown]
# Evaluating the model to know the accuracy of the model.

# %%
y_pred = model.predict(x_test)
# Out:
# 6/6 [==============================] - 3s 472ms/step

# %% [markdown]
# Next we will use our model to predict predicting the testing dataset label.

# %%
# Plotting image to compare
img = array_to_img(x_test[10])
img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
# Finding max value from predition list and comaparing original value vs predicted
print("Originally : ",all_labels[np.argmax(y_test[10])])
print("Predicted : ",all_labels[np.argmax(y_pred[10])])
# Out:
# Originally :  Potato-Early_blight
# Predicted :  Potato-Early_blight
